# %%
# Importar librerías necesarias
import pandas as pd
import random
from datetime import datetime, timedelta
import string
from google.colab import drive
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# %%
# Montar Google Drive para acceder a los archivos
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run '/content/drive/MyDrive/1. Básico/Caso de Uso 3/3.etl/colab_app_example.py'
# Out:
# Final proceso

# %%
spark = SparkSession.builder.appName("BasicosNIF").getOrCreate()

# %%
df = spark.read.parquet("/content/drive/MyDrive/1. Básico/Caso de Uso 3/4.output/cuadrante_planuno/")

# %%
df.show()
# Out:
# +-----------+------------------+----------+---------------+----------+---------------------+--------------+-------------+-----+-----------------+
# |customer_id|fecha_alta_cliente|       hoy|diferencia_dias|antiguedad|planuno_quadrant_name|Exclusivos_3d3|movement_type|bajas|cuadrante_planuno|
# +-----------+------------------+----------+---------------+----------+---------------------+--------------+-------------+-----+-----------------+
# |   11244603|        2021-05-10|2022-01-30|            265|6-12 meses|         Previnculado|         Otros|         baja|    1|            BAJAS|
# |   11244603|        2021-05-10|2022-01-30|            265|6-12 meses|            Vinculado|         Otros|         baja|    1|            BAJAS|
# |   11244603|        2021-05-10|2022-01-30|            265|6-12 meses|         Previnculado|         Otros|         baja|    1|            BAJAS|
# ...

# %%
# !pytest "/content/drive/MyDrive/1. Básico/Caso de Uso 3/3.etl/test_app.py" -v #-s
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content
# plugins: typeguard-4.5.2, langsmith-0.8.15, anyio-4.13.0
# collected 6 items
#
# drive/MyDrive/1. Básico/Caso de Uso 3/3.etl/test_app.py::test_get_base PASSED [ 16%]
# drive/MyDrive/1. Básico/Caso de Uso 3/3.etl/test_app.py::test_get_antiguedad PASSED [ 33%]
# drive/MyDrive/1. Básico/Caso de Uso 3/3.etl/test_app.py::test_get_refundidos PASSED [ 50%]
# drive/MyDrive/1. Básico/Caso de Uso 3/3.etl/test_app.py::test_get_clasificacion PASSED [ 66%]
# drive/MyDrive/1. Básico/Caso de Uso 3/3.etl/test_app.py::test_get_union PASSED [ 83%]
# drive/MyDrive/1. Básico/Caso de Uso 3/3.etl/test_app.py::test_get_cuadrante PASSED [100%]
#
# ============================== 6 passed in 20.67s ==============================
